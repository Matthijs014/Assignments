# %% [markdown]
# # Exam R
# Mark Klik & Misja Mikkers
#
# # Introduction
#
# The exam consists of 2 parts. In the first part, you have to run a regression, test if the assumptions of a linear regression model are met, and make 2 graphs.
#
# In the second part of the exam, you will have to make a map of Catholic and Protestant schools in the Netherlands.
#
# # Packages

# %%
library(tidyverse)
library(gvlma)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# <U+221A> ggplot2 2.2.1     <U+221A> purrr   0.2.4
# <U+221A> tibble  1.4.2     <U+221A> dplyr   0.7.4
# <U+221A> tidyr   0.8.0     <U+221A> stringr 1.3.0
# <U+221A> readr   1.1.1     <U+221A> forcats 0.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Assignment 1
#
#
# ## Data
#
# The data are given:

# %%
set.seed(123)
df1 <- as.data.frame(matrix(runif(1*50, min = 1, max = 10), ncol = 1)) %>%
    mutate(epsilon = rnorm(50, mean = 0, sd = 2)) %>%
    mutate(response = 3 - 2* V1  + epsilon) %>%
    mutate(group = ifelse(V1 <= 5, 1,2))

# %% [markdown]
# ## Asignment 1a
#
# The first assigment is to make boxplot using ggplot with group on the x-axis and V1 on the y-axis.

# %%
ggplot(df1, aes(x = group, y = V1)) + geom_boxplot()
# Out:
# Warning message:
# "Continuous x aesthetic -- did you forget aes(group=...)?"
# plot without title

# %% [markdown]
# ## Assignment 1b
#
# Run a regression with response variable as a function of V1.
# Show the summary statistics of the regression.

# %%
reg1 <- lm(data = df1, response ~ V1)
summary(reg1)
# Out:
# Call:
# lm(formula = response ~ V1, data = df1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.5116 -1.1157 -0.1313  1.0985  4.3723
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.6305     0.6347   4.145 0.000138 ***
# V1           -1.9152     0.1014 -18.880  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.881 on 48 degrees of freedom
# Multiple R-squared:  0.8813,	Adjusted R-squared:  0.8788
# F-statistic: 356.4 on 1 and 48 DF,  p-value: < 2.2e-16

# %% [markdown]
# check if the assumptions of linear regression are met with the `gvlma()` function.

# %%
gvlma(reg1)
# Out:
# Call:
# lm(formula = response ~ V1, data = df1)
#
# Coefficients:
# (Intercept)           V1
#       2.630       -1.915
#
#
# ASSESSMENT OF THE LINEAR MODEL ASSUMPTIONS
# USING THE GLOBAL TEST ON 4 DEGREES-OF-FREEDOM:
# Level of Significance =  0.05
#
# Call:
#  gvlma(x = reg1)
#
#                       Value p-value                Decision
# Global Stat        0.654319  0.9568 Assumptions acceptable.
# Skewness           0.002398  0.9609 Assumptions acceptable.
# Kurtosis           0.007200  0.9324 Assumptions acceptable.
# Link Function      0.005852  0.9390 Assumptions acceptable.
# Heteroscedasticity 0.638869  0.4241 Assumptions acceptable.

# %% [markdown]
# ## Assignment 1c
#
# Make a scatterplot with:
# * V1 on the x-axis and the response on the y-axis
# * Include the regression line in red with confidence interval
# * In a classic theme
# * The x-axis should be labeled "Predictor", the y-axis should be labeled ("Response")

# %%
ggplot(df1, aes(x = V1, y = response)) + 
    geom_point() + 
    geom_smooth(method = "lm", se = FALSE, color = 'red', ) +
    theme_classic() +
    xlab("Predictor") +
    ylab("Response")
# Out:
# plot without title

# %% [markdown]
# # Assigment 2
#
# # Packages

# %%
library(thematicmaps)
library(tidyverse)
# Out:
# Loading required package: maptools
# Loading required package: sp
# Checking rgeos availability: TRUE
# Loading required package: digest
# Loading required package: rgdal
# rgdal: version: 1.2-16, (SVN revision 701)
#  Geospatial Data Abstraction Library extensions to R successfully loaded
#  Loaded GDAL runtime: GDAL 2.1.2, released 2016/10/24
#  Path to GDAL shared files: /usr/share/gdal/2.1
#  GDAL binary built with GEOS: TRUE
#  Loaded PROJ.4 runtime: Rel. 4.9.3, 15 August 2016, [PJ_VERSION: 493]
#  Path to PROJ.4 shared files: (autodetected)
#  Linking to sp version: 1.2-4
# Loading required package: rgeos
# rgeos version: 0.3-26, (SVN revision 560)
#  GEOS runtime version: 3.5.1-CAPI-1.9.1 r4246
#  Linking to sp version: 1.2-4
#  Polygon checking: TRUE
#
# Loading required package: grid

# %% [markdown]
# ## Assignment 2a
#
# First you have to read in the file "nld_municipal_map.csv".
# Hint: Look at the notebook of week 6 about maps.

# %%
map_municipal <- read.csv('../Sourcedata/nld_municipal_map.csv', sep = ';')
head(map_municipal)
# Out:
#   name       id x        y        order hole  piece group
# 1 Appingedam 0  251260.5 594393.8 1     FALSE 1     0.1
# 2 Appingedam 0  251427.8 594486.7 2     FALSE 1     0.1
# 3 Appingedam 0  251668.8 594646.8 3     FALSE 1     0.1
# 4 Appingedam 0  251713.5 594770.9 4     FALSE 1     0.1
# 5 Appingedam 0  251354.6 595461.4 5     FALSE 1     0.1
# 6 Appingedam 0  251310.3 596022.5 6     FALSE 1     0.1

# %% [markdown]
# ## Assignment 2b
#
# Now you can make an empty map of the Netherlands.

# %%
AddMapLayer(MapPlot(), map_municipal)
# Out:
# plot without title

# %% [markdown]
# ## Assignment 2c
#
# Read in the pc4 locations (nld_pc4_locations.csv).
#
# Hint: Don't forget the X and Y should be numeric variables!

# %%
pc4_locations <- read.csv2('../Sourcedata/nld_pc4_locations.csv') %>%
    mutate(X = as.numeric(as.character(X))) %>%
    mutate(Y = as.numeric(as.character(Y)))

str(pc4_locations)
# Out:
# 'data.frame':	4066 obs. of  3 variables:
#  $ PC4: int  1011 1012 1013 1014 1015 1016 1017 1018 1019 1021 ...
#  $ X  : num  122244 121613 120325 119515 120740 ...
#  $ Y  : num  487223 487555 489672 489422 488009 ...

# %% [markdown]
# ## Assignment 2d
#
# ### 2di
#
# Read in the school data

# %%
schools <- read.csv('../Sourcedata/schools.csv', sep = ';')
head(schools)
# Out:
#   PROVINCIE            BEVOEGD.GEZAG.NUMMER BRIN.NUMMER VESTIGINGSNUMMER
# 1                      41152                23HC        23HC04
# 2 Drenthe              10053                18BR        18BR00
# 3 Drenthe              10053                18BR        18BR01
# 4 Drenthe              13273                20LO        20LO00
# 5 Drenthe              13273                20LO        20LO01
# 6 Drenthe              13273                20LO        20LO02
#   VESTIGINGSNAAM
# 1 RSG Lingecollege
# 2 School voor Praktijkonderwijs Assen
# 3 School voor Praktijkonderwijs Assen
# 4 Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo
# 5 Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo
# 6 Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo
#   STRAATNAAM               HUISNUMMER.TOEVOEGING POSTCODE
# 1
# 2 Zwartwatersweg           202                   9406 NN
# 3 Bosrand                  2                     9401 SL
# 4 Mr Groen v Prinstererln  98                    9402 KG
# 5 Schoolstraat             1                     9331 AV
# 6 Esdoornlaan              2                     9411 AV
#   PLAATSNAAM               GEMEENTENUMMER ... RPA.GEBIED.CODE
# 1                            NA           ... NA
# 2 ASSEN                     106           ...  3
# 3 ASSEN                     106           ...  3
# 4 ASSEN                     106           ...  3
# 5 NORG                     1699           ...  3
# 6 BEILEN                   1731           ...  5
#   RPA.GEBIED.NAAM          WGR.GEBIED.CODE
# 1                          NA
# 2 Centraal-Groningen        7
# 3 Centraal-Groningen        7
# 4 Centraal-Groningen        7
# 5 Centraal-Groningen        7
# 6 Zuid- en Midden-Drenthe   7
#   WGR.GEBIED.NAAM                         COROPGEBIED.CODE
# 1                                         NA
# 2 Noord- en Midden-Drenthe                 7
# 3 Noord- en Midden-Drenthe                 7
# 4 Noord- en Midden-Drenthe                 7
# 5 Noord- en Midden-Drenthe                 7
# 6 Noord- en Midden-Drenthe                 7
#   COROPGEBIED.NAAM                    ONDERWIJSGEBIED.CODE
# 1                                     NA
# 2 Noord-Drenthe                        4
# 3 Noord-Drenthe                        4
# 4 Noord-Drenthe                        4
# 5 Noord-Drenthe                        1
# 6 Noord-Drenthe                        4
#   ONDERWIJSGEBIED.NAAM             RMC.REGIO.CODE
# 1                                  NA
# 2 Assen-Hoogeveen-Emmen             7
# 3 Assen-Hoogeveen-Emmen             7
# 4 Assen-Hoogeveen-Emmen             7
# 5 Groningen en omstreken            7
# 6 Assen-Hoogeveen-Emmen             7
#   RMC.REGIO.NAAM
# 1
# 2 Noord- en Midden Drenthe
# 3 Noord- en Midden Drenthe
# 4 Noord- en Midden Drenthe
# 5 Noord- en Midden Drenthe
# 6 Noord- en Midden Drenthe

# %% [markdown]
# ### 2dii
#
# First, create a new dataframe schools1, which is equal to schools.
#
# As you see POSTCODE has a structure of (1234 AB). You should create a new variable PC4 that is equal to the first 4 numbers in POSTCODE
#
# Hint: Use the function `substr()`
#
# Then select the variables PC4 and DENOMINATIE

# %%
schools1 <- schools %>%
    mutate(PC4 = substr(schools$POSTCODE, 1, 4))

select(schools1, PC4, DENOMINATIE)
# Out:
#      PC4  DENOMINATIE
# 1         Openbaar
# 2    9406 Openbaar
# 3    9401 Openbaar
# 4    9402 Openbaar
# 5    9331 Openbaar
# 6    9411 Openbaar
# 7    9461 Openbaar
# 8    9402 Openbaar
# 9    9402 Openbaar
# 10   9403 Openbaar
# 11   9406 Openbaar
# 12   7905 Openbaar
# 13   7905 Openbaar
# 14   7905 Openbaar
# 15   7905 Openbaar
# 16   7905 Openbaar
# 17   9404 Algemeen bijzonder
# 18   9761 Algemeen bijzonder
# 19   7812 Algemeen bijzonder
# 20   7944 Algemeen bijzonder
# 21   7944 Algemeen bijzonder
# 22   7824 Rooms-Katholiek
# 23   9301 Algemeen bijzonder
# 24   9301 Algemeen bijzonder
# 25   7902 Protestants-Christelijk
# 26   7903 Protestants-Christelijk
# 27   7822 Protestants-Christelijk
# 28   7825 Algemeen bijzonder
# 29   7943 Openbaar
# 30   7943 Openbaar
# ...  ...  ...
# 1574 2231 Protestants-Christelijk
# 1575 2313 Rooms-Katholiek
# 1576 2371 Rooms-Katholiek
# 1577 2334 Rooms-Katholiek
# 1578 2334 Rooms-Katholiek
# 1579 4205 Protestants-Christelijk
# 1580 3371 Protestants-Christelijk
# 1581 4205 Protestants-Christelijk
# 1582 4204 Protestants-Christelijk
# 1583 4205 Protestants-Christelijk
# 1584 4207 Protestants-Christelijk
# 1585 4143 Protestants-Christelijk
# 1586 4142 Protestants-Christelijk
# 1587 3032 Algemeen bijzonder
# 1588 3039 Algemeen bijzonder
# 1589 2517 Protestants-Christelijk
# 1590 2551 Protestants-Christelijk
# 1591 3362 Samenwerking PC, Alg. Bijz.
# 1592 2241 Rooms-Katholiek
# 1593 3055 Rooms-Katholiek
# 1594 2401 Rooms-Katholiek
# 1595 2421 Rooms-Katholiek
# 1596 2585 Algemeen bijzonder
# 1597 2725 Rooms-Katholiek
# 1598 2614 Protestants-Christelijk
# 1599 2625 Protestants-Christelijk
# 1600 2625 Protestants-Christelijk
# 1601 2597 Antroposofisch
# 1602 3034 Antroposofisch
# 1603 2315 Antroposofisch

# %% [markdown]
# ### 2diii
#
# Create the dataframe school_loc as a join from pc4_locations and school1 that combines the columns from both data frames, but only keeps rows where the value in the pc4_locations column matches in both data frames.
# And then select the observations with DENOMINATIE is equal to "Rooms-Katholiek" or "Protestants-Christelijk"

# %%
school_loc <- merge(pc4_locations, schools1, domain = NA)
head(school_loc)
# Out:
#   PC4  X        Y        PROVINCIE     BEVOEGD.GEZAG.NUMMER BRIN.NUMMER
# 1 1013 120324.5 489671.7 Noord-Holland 42621                21ET
# 2 1013 120324.5 489671.7 Noord-Holland 40586                30GC
# 3 1014 119515.0 489421.7 Noord-Holland 67107                02PA
# 4 1014 119515.0 489421.7 Noord-Holland 42621                17HB
# 5 1016 120537.8 487075.4 Noord-Holland 40586                17YS
# 6 1017 121225.7 486219.9 Noord-Holland 13556                21AB
#   VESTIGINGSNUMMER
# 1 21ET12
# 2 30GC00
# 3 02PA00
# 4 17HB07
# 5 17YS21
# 6 21AB00
#   VESTIGINGSNAAM
# 1 Scholengemeenschap Amsterdam-Zuid voor Atheneum Havo Mavo Vbo Lwoo
# 2 Het 4e Gymnasium
# 3 Stichting Media Amsterdam
# 4 Scholengemeenschap ZAAM West voorVwo Havo Mavo Vbo Lwoo
# 5 Esprit Scholen voor Lyceum Havo Mavo Vbo Lwoo
# 6 Barlaeus Gymnasium
#   STRAATNAAM              HUISNUMMER.TOEVOEGING ... RPA.GEBIED.CODE
# 1 Haarlemmerstraat        132-136               ... 20
# 2 Archangelweg            4                     ... 20
# 3 Contactweg              36                    ... 20
# 4 Zekeringstraat          38-+40                ... 20
# 5 Tweede Passeerdersdwstr 9                     ... 20
# 6 Weteringschans          31                    ... 20
#   RPA.GEBIED.NAAM         WGR.GEBIED.CODE WGR.GEBIED.NAAM
# 1 Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 2 Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 3 Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 4 Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 5 Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 6 Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
#   COROPGEBIED.CODE COROPGEBIED.NAAM ONDERWIJSGEBIED.CODE ONDERWIJSGEBIED.NAAM
# 1 23               Groot-Amsterdam  15                   Zuid-Noord-Holland
# 2 23               Groot-Amsterdam  15                   Zuid-Noord-Holland
# 3 23               Groot-Amsterdam  15                   Zuid-Noord-Holland
# 4 23               Groot-Amsterdam  15                   Zuid-Noord-Holland
# 5 23               Groot-Amsterdam  15                   Zuid-Noord-Holland
# 6 23               Groot-Amsterdam  15                   Zuid-Noord-Holland
#   RMC.REGIO.CODE RMC.REGIO.NAAM
# 1 21             Agglomeratie Amsterdam
# 2 21             Agglomeratie Amsterdam
# 3 21             Agglomeratie Amsterdam
# 4 21             Agglomeratie Amsterdam
# 5 21             Agglomeratie Amsterdam
# 6 21             Agglomeratie Amsterdam

# %% [markdown]
# ## Assignment 2e
#
# Create a map of Catholic and Protestant schools in the Netherlands

# %%
AddMapLayer(MapPlot(), map_municipal) %>%
    AddPointsLayer(school_loc, columnNameColor = "DENOMINATIE")
# Out:
# plot without title

# %% [markdown]
# End of notebook
